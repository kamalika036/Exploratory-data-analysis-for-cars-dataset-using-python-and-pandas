# %%
2+2
# Out:
# 4

# %%
'''
the process of eda is 
1) knowing initials details about data 
2) modifying or removing unwanted data
3) retriving the data
4) getting satistical infromation
5) drawing graphs or plots
  '''
# Out:
# '\nthe process of eda is \n1) knowing initials details about data \n2) modifying or removing unwanted data\n3) retriving the data\n4) getting satistical infromation\n5) drawing graphs or plots\n  '

# %%
import pandas as pd
imposrt seaborn as sns
# Out:
#   Cell In[3], line 2
#     imposrt seaborn as sns
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 import pandas as pd
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/155.5 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/155.5 kB 660.6 kB/s eta 0:00:01
#      --------- --------------------------- 41.0/155.5 kB 653.6 kB/s eta 0:00:01
#      ----------------- ------------------- 71.7/155.5 kB 563.7 kB/s eta 0:00:01
#      -------------------------- --------- 112.6/155.5 kB 595.3 kB/s eta 0:00:01
#      ---------------------------- ------- 122.9/155.5 kB 602.4 kB/s eta 0:00:01
#      -----------------------------------  153.6/155.5 kB 541.0 kB/s eta 0:00:01
#      ------------------------------------ 155.5/155.5 kB 517.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.6 kB 435.7 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/294.6 kB 393.8 kB/s eta 0:00:01
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
cars=pd.read_csv("cars.csv")

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
cars.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 424  $40,083          2.3        5.0         242        20           26
# 425  $42,573          2.9        6.0         268        19           26
# 426  $24,641          1.9        4.0         170        22           29
# 427  $33,112          2.5        5.0         208        20           27
# 428  $33,112          2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 424    3450        105     186
# 425    3653        110     190
# ...

# %%
cars.tail(30)
# Out:
#            Make                           Model   Type  Origin DriveTrain  \
# 399      Toyota        Tundra Access Cab V6 SR5  Truck    Asia        All
# 400      Toyota                       Matrix XR  Wagon    Asia      Front
# 401  Volkswagen                      Touareg V6    SUV  Europe        All
# 402  Volkswagen                    Golf GLS 4dr  Sedan  Europe      Front
# 403  Volkswagen              GTI 1.8T 2dr hatch  Sedan  Europe      Front
# 404  Volkswagen               Jetta GLS TDI 4dr  Sedan  Europe      Front
# 405  Volkswagen         New Beetle GLS 1.8T 2dr  Sedan  Europe      Front
# 406  Volkswagen               Jetta GLI VR6 4dr  Sedan  Europe      Front
# 407  Volkswagen  New Beetle GLS convertible 2dr  Sedan  Europe      Front
# 408  Volkswagen                  Passat GLS 4dr  Sedan  Europe      Front
# 409  Volkswagen       Passat GLX V6 4MOTION 4dr  Sedan  Europe      Front
# 410  Volkswagen           Passat W8 4MOTION 4dr  Sedan  Europe      Front
# ...

# %%
cars.shape
# Out:
# (429, 15)

# %%
r,c=cars.shape

# %%
r
# Out:
# 429

# %%
c
# Out:
# 15

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         429 non-null    object
#  1   Model        429 non-null    object
#  2   Type         429 non-null    object
#  3   Origin       429 non-null    object
#  4   DriveTrain   429 non-null    object
#  5   MSRP         429 non-null    object
#  6   Invoice      429 non-null    object
#  7   EngineSize   429 non-null    float64
#  8   Cylinders    427 non-null    float64
#  9   Horsepower   429 non-null    int64
#  10  MPG_City     429 non-null    int64
#  11  MPG_Highway  429 non-null    int64
#  12  Weight       429 non-null    int64
#  13  Wheelbase    429 non-null    int64
#  14  Length       429 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.4+ KB

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
#remove unimportant columns like MSRP nad Invoice
cars=cars.drop(['MSRP','Invoice'],axis=1)

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain  EngineSize  \
# 0    Acura                      MDX    SUV    Asia        All         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 3    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 426  Volvo                      V40  Wagon  Europe      Front         1.9
# 427  Volvo                     XC70  Wagon  Europe        All         2.5
# 428  Volvo                     XC70  Wagon  Europe        All         2.5
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
#remove duplicate rows if any and keep the first row and remove other duplicate other rows
cars=cars.drop_duplicates(keep='first')

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain  EngineSize  \
# 0    Acura                      MDX    SUV    Asia        All         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 3    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 426  Volvo                      V40  Wagon  Europe      Front         1.9
# 427  Volvo                     XC70  Wagon  Europe        All         2.5
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
#find the total no of rows which are missing values of columns
cars.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
#remove thw rows having missing vakues . in our case cylinder
cars.dropna(inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_4432\560717047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.dropna(inplace=True)

# %%
cars.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
#q1 show the sorted data in descending order on mpg_city
cars_sort= cars.sort_values(by='MPG_City', ascending=False)

# %%
cars_sort
# Out:
#            Make                                   Model    Type  Origin  \
# 150       Honda              Insight 2dr (gas/electric)  Hybrid    Asia
# 373      Toyota                Prius 4dr (gas/electric)  Hybrid    Asia
# 149       Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid    Asia
# 404  Volkswagen                       Jetta GLS TDI 4dr   Sedan  Europe
# 155       Honda                            Civic HX 2dr   Sedan    Asia
# ..          ...                                     ...     ...     ...
# 216  Land Rover                            Discovery SE     SUV  Europe
# 215  Land Rover                         Range Rover HSE     SUV  Europe
# 114       Dodge            Viper SRT-10 convertible 2dr  Sports     USA
# 166      Hummer                                      H2     SUV     USA
# 118        Ford                       Excursion 6.8 XLT     SUV     USA
#
#     DriveTrain  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars_sort= cars.sort_values(by='MPG_City', descending=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 cars_sort= cars.sort_values(by='MPG_City', descending=True)
#
# TypeError: DataFrame.sort_values() got an unexpected keyword argument 'descending'

# %%
#summary the statistics if std=0 thn that column should be removed from that analysis
cars.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  426.000000  426.000000  426.000000  426.000000   426.000000
# mean     3.205634    5.807512  215.877934   20.070423    26.854460
# std      1.103520    1.558443   71.991040    5.248616     5.752335
# min      1.400000    3.000000   73.000000   10.000000    12.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.750000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   426.000000  426.000000  426.000000
# mean   3580.474178  108.164319  186.420188
# std     759.870073    8.330030   14.366611
# min    1850.000000   89.000000  143.000000
# 25%    3111.250000  103.000000  178.000000
# 50%    3476.000000  107.000000  187.000000
# 75%    3979.250000  112.000000  194.000000
# ...

# %%
#to know the relationship between numeric columns we can use corr() method on the dataframe
cars.corr(method='pearson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 #to know the relationship between numeric columns we can use corr() method on the dataframe
# ----> 2 cars.corr(method='pearson')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
cars.corr(method='pearson')['MPG_City']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 cars.corr(method='pearson')['MPG_City']
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
# ...

# %%
#to select only numeric type columns 
cars1= cars[['EngineSize','Cylinders','Horsepower','MPG_City','MPG_Highway','Weight','Wheelbase','Length'         ]]

# %%
cars1
# Out:
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0           3.5        6.0         265        17           23    4451
# 1           2.0        4.0         200        24           31    2778
# 2           2.4        4.0         200        22           29    3230
# 3           3.2        6.0         270        20           28    3575
# 4           3.5        6.0         225        18           24    3880
# ..          ...        ...         ...       ...          ...     ...
# 423         2.4        5.0         197        21           28    3450
# 424         2.3        5.0         242        20           26    3450
# 425         2.9        6.0         268        19           26    3653
# 426         1.9        4.0         170        22           29    2822
# 427         2.5        5.0         208        20           27    3823
#
#      Wheelbase  Length
# 0          106     189
# 1          101     172
# 2          105     183
# 3          108     186
# ...

# %%
cars1.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  426.000000  426.000000  426.000000  426.000000   426.000000
# mean     3.205634    5.807512  215.877934   20.070423    26.854460
# std      1.103520    1.558443   71.991040    5.248616     5.752335
# min      1.400000    3.000000   73.000000   10.000000    12.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.750000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   426.000000  426.000000  426.000000
# mean   3580.474178  108.164319  186.420188
# std     759.870073    8.330030   14.366611
# min    1850.000000   89.000000  143.000000
# 25%    3111.250000  103.000000  178.000000
# 50%    3476.000000  107.000000  187.000000
# 75%    3979.250000  112.000000  194.000000
# ...

# %%
cars1.corr(method='pearson')
# Out:
#              EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# EngineSize     1.000000   0.908002    0.793250 -0.717860    -0.725901
# Cylinders      0.908002   1.000000    0.810341 -0.684402    -0.676100
# Horsepower     0.793250   0.810341    1.000000 -0.677034    -0.647425
# MPG_City      -0.717860  -0.684402   -0.677034  1.000000     0.940993
# MPG_Highway   -0.725901  -0.676100   -0.647425  0.940993     1.000000
# Weight         0.808707   0.742209    0.631758 -0.740418    -0.793615
# Wheelbase      0.638947   0.546730    0.387561 -0.508029    -0.525457
# Length         0.636015   0.547783    0.382386 -0.504184    -0.468756
#
#                Weight  Wheelbase    Length
# EngineSize   0.808707   0.638947  0.636015
# Cylinders    0.742209   0.546730  0.547783
# Horsepower   0.631758   0.387561  0.382386
# MPG_City    -0.740418  -0.508029 -0.504184
# MPG_Highway -0.793615  -0.525457 -0.468756
# Weight       1.000000   0.760857  0.689168
# ...

# %%
cars1.corr(method='pearson')['MPG_City']
# Out:
# EngineSize    -0.717860
# Cylinders     -0.684402
# Horsepower    -0.677034
# MPG_City       1.000000
# MPG_Highway    0.940993
# Weight        -0.740418
# Wheelbase     -0.508029
# Length        -0.504184
# Name: MPG_City, dtype: float64

# %%
#plot: display distribution plot with kernal dencity take mpg_city on xaxis

sns.displot(data=cars1, x='MPG_City', bins=10, kde=True, color='blue')

# %%
#draw regresion plot between length of the car and milage in city
sns.regplot(x='Length',y='MPG_City', data=cars1)
# Out:
# <Axes: xlabel='Length', ylabel='MPG_City'>

# %%
#create a boxplot for categorical variables where the deduction should be sub gives less miolage and hybrid gives more milage
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain  EngineSize  \
# 0    Acura                      MDX    SUV    Asia        All         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 3    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 426  Volvo                      V40  Wagon  Europe      Front         1.9
# 427  Volvo                     XC70  Wagon  Europe        All         2.5
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# ...

# %%
box1=sns.boxplot(x='Type',y='MPG_City', data=cars)

# %%
#origin of car asia slights gives more milage
box2=sns.boxplot(x='Origin',y='MPG_City', data=cars)

# %%
#draw the pair plot between all columns
sns.pairplot(cars,hue='Origin')
